# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
inout = pd.read_csv("DataSets/INOUT.csv")
#line = pd.read_csv("DataSets/INOUTLINE.csv", low_memory=False)
#prodins = pd.read_csv("DataSets/PRODUCTINSTANCE.csv", encoding='cp1252', low_memory=False)
#prod = pd.read_csv("DataSets/PRODUCTS.csv", low_memory=False)
#transitem = pd.read_csv("DataSets/TRANSFER_ITEM.csv", low_memory=False)
#transitemd = pd.read_csv("DataSets/TRANSFER_ITEM_D.csv", low_memory=False)

# %%
inout.head()
# Out:
#     INOUT_ID  AD_CLIENT_ID  AD_ORG_ID ISACTIVE         CREATED  CREATEDBY  \
# 0  469637755     104000002          0        Y  6/28/2015 7:50  210619032
# 1  469637756     104000002          0        Y  6/28/2015 7:50  210619032
# 2  469637757     104000002          0        Y  6/28/2015 7:50  210619032
# 3  469637758     104000002          0        Y  6/28/2015 7:50  210619032
# 4  469637759     104000002          0        Y  6/28/2015 7:50  210619032
#
#            UPDATED  UPDATEDBY  NAME DESCRIPTION  ... STRING3  \
# 0  11/8/2017 11:15  210033614   NaN          69  ...     NaN
# 1   6/28/2015 7:50  210619032   NaN          73  ...     NaN
# 2   6/28/2015 7:50  210619032   NaN         206  ...     NaN
# 3   6/28/2015 7:50  210619032   NaN        9405  ...     NaN
# 4   6/28/2015 7:50  210619032   NaN         346  ...     NaN
#
#    M_INOUT_AMVAL_ID  DOCUMENTNO1 LOCATIONS_ID ACCT_AC_HOLDING_ID   VAHED_MALI  \
# 0               NaN         69.0          NaN                1.0  200000138.0
# 1               NaN         73.0          NaN                1.0  200000138.0
# 2               NaN        206.0          NaN                1.0  200000138.0
# 3               NaN       9405.0          NaN                1.0  200000138.0
# 4               NaN        346.0          NaN                1.0  200000138.0
#
#    ACCT_AC_JOURNAL_ID  BASEINFO_RECORDID  C_YEAR_ID  Unnamed: 43
# 0         470900574.0                NaN        NaN          NaN
# 1         470900574.0                NaN        NaN          NaN
# 2         470900574.0                NaN        NaN          NaN
# 3         470900574.0                NaN        NaN          NaN
# 4         470900574.0                NaN        NaN          NaN
#
# [5 rows x 44 columns]

# %%
x=[]
for i in range(7600):
    if inout.loc[i,['DOCUMENTNO']].isnull().bool():
        x.append(inout.loc[i,:])

# %%
df = pd.DataFrame(x)
df.head()
# Out:
#        INOUT_ID  AD_CLIENT_ID  AD_ORG_ID ISACTIVE          CREATED  CREATEDBY  \
# 19    210032665     104000002          0        Y  12/26/2013 9:49  210035294
# 3297  469641113     104000002          0        Y   1/9/2018 13:28  210032662
#
#               UPDATED  UPDATEDBY  NAME DESCRIPTION  ... STRING3  \
# 19    12/26/2013 9:50  210035294   NaN         NaN  ...     NaN
# 3297   1/9/2018 13:32  210032662   NaN           p  ...     NaN
#
#       M_INOUT_AMVAL_ID  DOCUMENTNO1 LOCATIONS_ID ACCT_AC_HOLDING_ID  \
# 19                 NaN          NaN          NaN                1.0
# 3297               NaN          NaN          NaN                NaN
#
#       VAHED_MALI  ACCT_AC_JOURNAL_ID  BASEINFO_RECORDID  C_YEAR_ID  \
# 19           NaN                 NaN                NaN        NaN
# 3297         1.0         200000138.0        470900619.0        NaN
#
#       Unnamed: 43
# 19            NaN
# 3297          NaN
#
# [2 rows x 44 columns]

# %%
a=[]
acount=0
for i in range(7600):
    if (inout.loc[i,['C_DOCSTATUS_ID']]==3000025).bool():
        a.append(inout.loc[i,:])
        acount+=1
        
        
print(acount)
df2 = pd.DataFrame(a)
df2.head()
# Out:
# 7583
#     INOUT_ID  AD_CLIENT_ID  AD_ORG_ID ISACTIVE         CREATED  CREATEDBY  \
# 0  469637755     104000002          0        Y  6/28/2015 7:50  210619032
# 1  469637756     104000002          0        Y  6/28/2015 7:50  210619032
# 2  469637757     104000002          0        Y  6/28/2015 7:50  210619032
# 3  469637758     104000002          0        Y  6/28/2015 7:50  210619032
# 4  469637759     104000002          0        Y  6/28/2015 7:50  210619032
#
#            UPDATED  UPDATEDBY  NAME DESCRIPTION  ...  STRING3  \
# 0  11/8/2017 11:15  210033614   NaN          69  ...      NaN
# 1   6/28/2015 7:50  210619032   NaN          73  ...      NaN
# 2   6/28/2015 7:50  210619032   NaN         206  ...      NaN
# 3   6/28/2015 7:50  210619032   NaN        9405  ...      NaN
# 4   6/28/2015 7:50  210619032   NaN         346  ...      NaN
#
#    M_INOUT_AMVAL_ID  DOCUMENTNO1 LOCATIONS_ID ACCT_AC_HOLDING_ID   VAHED_MALI  \
# 0               NaN         69.0          NaN                1.0  200000138.0
# 1               NaN         73.0          NaN                1.0  200000138.0
# 2               NaN        206.0          NaN                1.0  200000138.0
# 3               NaN       9405.0          NaN                1.0  200000138.0
# 4               NaN        346.0          NaN                1.0  200000138.0
#
#    ACCT_AC_JOURNAL_ID  BASEINFO_RECORDID  C_YEAR_ID  Unnamed: 43
# 0         470900574.0                NaN        NaN          NaN
# 1         470900574.0                NaN        NaN          NaN
# 2         470900574.0                NaN        NaN          NaN
# 3         470900574.0                NaN        NaN          NaN
# 4         470900574.0                NaN        NaN          NaN
#
# [5 rows x 44 columns]

# %%
b=[]
bcount=0
for i in range(7600):
    if (inout.loc[i,['C_DOCSTATUS_ID']]==3000006).bool():
        b.append(inout.loc[i,:])
        bcount+=1
        
        
print(bcount)
df3 = pd.DataFrame(b)
df3.head()
# Out:
# 14
#        INOUT_ID  AD_CLIENT_ID  AD_ORG_ID ISACTIVE          CREATED  CREATEDBY  \
# 1466  469639217     104000002          0        Y  7/12/2016 15:09  210032662
# 2269  469640047     104000002          0        Y    3/7/2017 8:58  210032662
# 2270  469640048     104000002          0        Y    3/7/2017 9:01  210032662
# 2271  469640049     104000002          0        Y    3/7/2017 9:15  210032662
# 2990  469640796     104000002          0        Y  10/18/2017 8:19  210032662
#
#               UPDATED  UPDATEDBY  NAME  \
# 1466   9/3/2016 11:21  210032662   NaN
# 2269    3/7/2017 8:58  210032662   NaN
# 2270    3/7/2017 9:04  210032662   NaN
# 2271    3/7/2017 9:15  210032662   NaN
# 2990  10/18/2017 8:19  210032662   NaN
#
#                                             DESCRIPTION  ...  STRING3  \
# 1466  ???? ??????? ????? ?? ?????? ??????? ????? ???...  ...      NaN
# 2269                                                NaN  ...      NaN
# 2270                                                NaN  ...      NaN
# 2271                                                NaN  ...      NaN
# 2990                                                NaN  ...      NaN
#
#       M_INOUT_AMVAL_ID  DOCUMENTNO1 LOCATIONS_ID ACCT_AC_HOLDING_ID  \
# 1466               NaN          NaN          NaN                1.0
# 2269               NaN          NaN          NaN                1.0
# 2270               NaN          NaN          NaN                1.0
# 2271               NaN          NaN          NaN                1.0
# 2990               NaN          NaN          NaN                1.0
#
#        VAHED_MALI  ACCT_AC_JOURNAL_ID  BASEINFO_RECORDID  C_YEAR_ID  \
# 1466  200000138.0                 NaN                NaN        NaN
# 2269  200000138.0                 NaN                NaN        NaN
# 2270  200000138.0                 NaN                NaN        NaN
# 2271  200000138.0                 NaN                NaN        NaN
# 2990          NaN                 NaN                NaN        NaN
#
#       Unnamed: 43
# 1466          NaN
# 2269          NaN
# 2270          NaN
# 2271          NaN
# 2990          NaN
#
# [5 rows x 44 columns]

# %%
c=[]
ccount=0
for i in range(7600):
    if (inout.loc[i,['C_DOCSTATUS_ID']]==3000018).bool():
        c.append(inout.loc[i,:])
        ccount+=1
        
        
print(ccount)
df4 = pd.DataFrame(c)
df4.head()
# Out:
# 1
#      INOUT_ID  AD_CLIENT_ID  AD_ORG_ID ISACTIVE          CREATED  CREATEDBY  \
# 19  210032665     104000002          0        Y  12/26/2013 9:49  210035294
#
#             UPDATED  UPDATEDBY  NAME  DESCRIPTION  ...  STRING3  \
# 19  12/26/2013 9:50  210035294   NaN          NaN  ...      NaN
#
#     M_INOUT_AMVAL_ID  DOCUMENTNO1 LOCATIONS_ID ACCT_AC_HOLDING_ID  VAHED_MALI  \
# 19               NaN          NaN          NaN                1.0         NaN
#
#     ACCT_AC_JOURNAL_ID  BASEINFO_RECORDID  C_YEAR_ID  Unnamed: 43
# 19                 NaN                NaN        NaN          NaN
#
# [1 rows x 44 columns]
